# %%
#imports
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Subset, TensorDataset
from torchvision import datasets, transforms
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np

#save my life
#from google.colab import drive
#drive.mount("/content/drive")

# %%
#training parameters
nb_experiments = 3
nb_epochs_per_acquisition = 100
batch_size = 30
eval_batch_size=256
validation_set_size = 100
dropout_samples = 100
acquisition_iters = 100
points_acquire = 10

#model parameters
nb_filters = 32
nb_classes = 10
filter_size = 4
pool_size = 2
dense_size = 128
dropout_prob_1 = 0.25
dropout_prob_2 = 0.5

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

#define our model:
class BayesianCNN(nn.Module):
  def __init__(self):
    super().__init__()
    self.conv1 = nn.Conv2d(1, nb_filters, kernel_size=filter_size, padding=0)
    self.conv2 = nn.Conv2d(nb_filters, nb_filters, kernel_size=filter_size, padding=0)
    self.pool = nn.MaxPool2d(kernel_size=pool_size)
    self.dropout1 = nn.Dropout(p=dropout_prob_1)

    self.full1 = nn.Linear(32 * 11 * 11, dense_size)
    self.dropout2 = nn.Dropout(p=dropout_prob_2)
    self.ln1 = nn.LayerNorm(dense_size)
    self.full2 = nn.Linear(dense_size, nb_classes)

  def features(self, x):
    x = F.relu(self.conv1(x))
    x = F.relu(self.conv2(x))
    x = self.pool(x)
    x = torch.flatten(x, 1)
    #x = self.dropout1(x)
    x = F.relu(self.full1(x))
    #x = self.dropout2(x)
    x = self.ln1(x)
    return x

  def forward(self, x):
    x = F.relu(self.conv1(x))
    x = F.relu(self.conv2(x))
    x = self.pool(x)
    x = torch.flatten(x, 1)
    x = self.dropout1(x)
    x = F.relu(self.full1(x))
    x = self.dropout2(x)
    x = self.ln1(x)
    x = self.full2(x)
    return x

  def frozeninf(self, x, post_mu):
    x = self.features(x)
    if x.dim() == 1:
      x = x.unsqueeze(0)
    x = x @ post_mu
    return x

# %%
@torch.no_grad()
def eval_model_per_point(model, X_test, y_test, device):
  model = model.to(device)
  model.eval()

  X_test = X_test.to(device)
  y_test = y_test.to(device)

  out = model(X_test)
  y_onehot = F.one_hot(y_test, num_classes=10).float()
  err = ((out - y_onehot) ** 2).sum(dim=1)

  return err.detach().cpu().tolist()


@torch.no_grad()
def eval_model(model, X_test, y_test, device):
  model = model.to(device)
  model.eval()

  X_test = X_test.to(device)
  y_test = y_test.to(device)

  out = model(X_test)
  y_onehot = torch.nn.functional.one_hot(y_test, num_classes=10).float()
  sse = torch.sum((out - y_onehot) ** 2)
  total = y_onehot.numel()

  return (sse / total).sqrt().item()


@torch.no_grad()
def eval_model_frozen_inf(model, X_test, y_test, device, post_mu):
  model = model.to(device)
  model.eval()

  X_test = X_test.to(device)
  y_test = y_test.to(device)

  out = model.frozeninf(X_test, post_mu)
  y_onehot = torch.nn.functional.one_hot(y_test, num_classes=10).float()
  sse = torch.sum((out - y_onehot) ** 2)
  total = y_onehot.numel()

  return (sse / total).sqrt().item()

def train_model(model, X, y, X_val, y_val, optimizer, criterion, batch_size, device, nb_epochs):
  model.train()
  model.to(device)

  dloader = DataLoader(list(zip(X,y)), shuffle=True, batch_size=batch_size)
  patience = 10
  best_val_rmse = 10000
  bad_epochs = 0
  best_state = None

  for epoch in range(nb_epochs):
    model.train()
    train_sse = 0.0
    train_total = 0
    for x, y in dloader:
      x = x.to(device)
      y_onehot = torch.nn.functional.one_hot(y, num_classes=10).float()
      y_onehot = y_onehot.to(device)

      optimizer.zero_grad()
      output = model(x)
      mse = criterion(output, y_onehot)
      mse.backward()
      optimizer.step()

      train_sse += torch.sum((output.detach() - y_onehot) ** 2).item()
      train_total += y_onehot.numel()

    verbose = False

    if verbose:
     train_rmse = (train_sse / train_total) ** 0.5
     print(f"Train rmse {train_rmse}")

    #this was adopted from classification
    #so we need to change the criteria
    early_stopping = True
    if early_stopping:
      val_rmse = eval_model(model, X_val, y_val, device)
      model.train()
      if verbose:
        print(f"Epoch {epoch+1}: val rmse: {val_rmse}")

      if val_rmse <  best_val_rmse:
        best_val_rmse = val_rmse
        bad_epochs = 0
        best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
      else:
        bad_epochs += 1
        if bad_epochs >= patience:
          print(f"Early stopping at epoch {epoch+1}")
          break

  if best_state is not None:
    model.load_state_dict(best_state)
    model.to(device)


  return model

# %%
def sample_from_pool(X_pool, y_pool, seed=None):
  if seed is None:
    g = None
  else:
    g = torch.Generator(device=y_pool.device)
    g.manual_seed(seed)

  indices = []
  for label in range(nb_classes):
    class_indices = (y_pool == label).nonzero(as_tuple=True)[0]
    perm = torch.randperm(len(class_indices), generator=g, device=class_indices.device)
    class_indices = class_indices[perm]
    indices.append(class_indices[:2])
  return torch.cat(indices, dim=0)

# %%
#get the datasets
transform = transforms.Compose([
    transforms.ToTensor(),
])
train = datasets.MNIST(root="./data", train=True, download=True, transform=transform)
test = datasets.MNIST(root="./data", train=False, download=True, transform=transform)

X = torch.stack([train[i][0] for i in range(len(train))])
y = torch.tensor([train[i][1] for i in range(len(train))])

X_test = torch.stack([test[i][0] for i in range(len(test))])
y_test = torch.tensor([test[i][1] for i in range(len(test))])
# Out:
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 4.97MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 130kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.25MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 9.93MB/s]

# %%
def compute_predictive_variance_idid(model, X_pool_red, device, U):
  #computes predictive variance for pool
  model = model.to(device)
  model.eval()

  X_pool_red = X_pool_red.to(device)
  PhiX = model.features(X_pool_red)
  X_pool_red = X_pool_red.to("cpu")
  sigma_star = torch.sum(PhiX @ U * PhiX, dim = 1) #faster

  #print("shape analysis")
  #print(f'phix shape {PhiX.shape}')
  #print(f'U shape {U.shape}')
  #print(f'PhiTPhi shape {PhiTPhi.shape}')
  #print(f'Sigma star shape {sigma_star.shape}')

  return sigma_star

# %%
def compute_posterior_params_idid(model, X_train, Y_train, s, sigma, device):
  s_coeff = s
  sigma_coeff = sigma

  model = model.to(device)
  model.eval()

  X_train = X_train.to(device)
  Y_train_onehot = torch.nn.functional.one_hot(Y_train, num_classes=10).float().to(device)

  Phi = model.features(X_train)
  K = Phi.shape[1]

  PhiTPhi = Phi.T @ Phi

  U = torch.linalg.inv(torch.eye(K, device=device) * (1 / s_coeff**2) + PhiTPhi * (1 / sigma_coeff**2))
  M = (U @ (Phi.T @ Y_train_onehot)) * (1 / sigma_coeff**2)

  return U, M

# %%
def compute_random(model, X_pool_red, device, U):
  return torch.rand(X_pool_red.shape[0])

# %%
def run_experiment_regression(X, y, X_test, y_test, acquisitions = None):
  perm_g = torch.Generator()
  perm = torch.randperm(len(X), generator=perm_g)
  X = X[perm]
  y = y[perm]
  X_valid = X[:validation_set_size]
  y_valid = y[:validation_set_size]
  X_pool_orig = X[validation_set_size:]
  y_pool_orig = y[validation_set_size:]
  train_idx = sample_from_pool(X_pool_orig, y_pool_orig)

  accs_for_acquisitons = [[] for _ in range(len(acquisitions))]
  for acq in range(len(acquisitions)):

    print(f'Creating training dataset')
    X_train = X_pool_orig[train_idx]
    y_train = y_pool_orig[train_idx]

    mask = torch.ones(len(X_pool_orig), dtype=torch.bool)
    mask[train_idx] = False
    X_pool = X_pool_orig[mask]
    y_pool = y_pool_orig[mask]


    print(f'Active learning: running for {acquisitions[acq][1]}')
    acq_name = acquisitions[acq][1]
    acq_func = acquisitions[acq][0]
    md = None
    accs = []
    stats = {i:0 for i in range(10)}

    for i in range(100):
      if i % 10 == 0:
        print(f'Starting acquisition iteration {i}')

      N = X_train.shape[0]
      s = 0.5
      sigma = 0.1
      modelAct = BayesianCNN()
      optimizer = torch.optim.Adam(modelAct.parameters(), lr=0.001,weight_decay = 2 * (sigma**2) / (N * (s**2)))
      criterion = nn.MSELoss()

      #train on the current training set
      modelAct = train_model(modelAct, X_train, y_train, X_valid, y_valid, optimizer, criterion, batch_size=batch_size, device=device, nb_epochs=nb_epochs_per_acquisition)

      #get BALD for all or almost all pool points?
      idx = torch.randperm(X_pool.size(0))[:1000]
      X_pool_red = X_pool[idx]
      y_pool_red = y_pool[idx]

      #compute posterior variance
      U, M = compute_posterior_params_idid(modelAct, X_train, y_train, s, sigma, device)
      score = acq_func(modelAct, X_pool_red, device, U)

      Queries = points_acquire

      topk_in_red = torch.topk(score, k=Queries).indices.to("cpu")
      chosen_idx = idx[topk_in_red]
      #for i in range(10):
      #  showimg(X_pool[chosen_idx[i]])
      #get statistics of classes chosen so far:
      for i in y_pool[chosen_idx]:
        stats[i.item()] += 1
      #print(stats)



      X_train = torch.cat([X_train, X_pool[chosen_idx]], dim=0)
      y_train = torch.cat([y_train, y_pool[chosen_idx]], dim=0)

      mask = torch.ones(X_pool.size(0), dtype=torch.bool)
      mask[chosen_idx] = False
      X_pool = X_pool[mask]
      y_pool = y_pool[mask]

      rmse = eval_model_frozen_inf(modelAct, X_test, y_test, device, M)
      modelAct.train()
      accs.append((rmse, X_train.shape[0] - Queries))
      print(f'RMSE: {rmse}')
      md = modelAct


    now = datetime.now()
    #save_path = "/content/drive/MyDrive/" + str(now.hour) + str(now.minute) + acq_name + "bayesian_cnn_mnist.pt"
    #torch.save(md.state_dict(), save_path)

    accs_for_acquisitons[acq] = accs

  return accs_for_acquisitons

# %%
funcs = [[compute_predictive_variance_idid, "pred_variance_naive"],[compute_random, "random"]]#[compute_predictive_variance_idid, "pred_variance_naive"], [compute_random, "random"]]
#get_score_err_plots(X, y, X_test, y_test, funcs)
regression_results_1 = run_experiment_regression(X, y, X_test, y_test, funcs)
regression_results_2 = run_experiment_regression(X, y, X_test, y_test, funcs)
regression_results_3 = run_experiment_regression(X, y, X_test, y_test, funcs)

avg_regression_results = []
for i in range(2):
  avg_regression_results.append([])
  for j in range(100):
    avg_regression_results[i].append([(regression_results_1[i][j][0] + regression_results_2[i][j][0] + regression_results_3[i][j][0]) / 3, regression_results_1[i][j][1]])
# Out:
# Creating training dataset
# Active learning: running for pred_variance_naive
# Starting acquisition iteration 0
# Early stopping at epoch 36
# RMSE: 0.24847179651260376
# Early stopping at epoch 96
# RMSE: 0.2769688367843628
# Early stopping at epoch 55
# RMSE: 0.26521819829940796
# Early stopping at epoch 51
# RMSE: 0.2539821267127991
# Early stopping at epoch 81
# RMSE: 0.22956623136997223
# RMSE: 0.21641623973846436
# Early stopping at epoch 87
# RMSE: 0.21022701263427734
# Early stopping at epoch 80
# RMSE: 0.20283305644989014
# Early stopping at epoch 99
# RMSE: 0.1949026733636856
# Early stopping at epoch 83
# RMSE: 0.18125829100608826
# Starting acquisition iteration 10
# Early stopping at epoch 72
# RMSE: 0.19963844120502472
# Early stopping at epoch 58
# RMSE: 0.1917724460363388
# Early stopping at epoch 82
# RMSE: 0.1765357255935669
# Early stopping at epoch 100
# RMSE: 0.16929024457931519
# Early stopping at epoch 44
# RMSE: 0.18298013508319855
# Early stopping at epoch 48
# RMSE: 0.18316298723220825
# Early stopping at epoch 96
# RMSE: 0.1553465574979782
# Early stopping at epoch 69
# RMSE: 0.15396375954151154
# Early stopping at epoch 66
# RMSE: 0.15720751881599426
# Early stopping at epoch 74
# RMSE: 0.14677678048610687
# Starting acquisition iteration 20
# Early stopping at epoch 71
# RMSE: 0.13444557785987854
# Early stopping at epoch 71
# RMSE: 0.14290651679039001
# Early stopping at epoch 96
# RMSE: 0.1294214427471161
# Early stopping at epoch 61
# RMSE: 0.12231051176786423
# Early stopping at epoch 63
# RMSE: 0.13474184274673462
# Early stopping at epoch 80
# RMSE: 0.11764958500862122
# Early stopping at epoch 73
# RMSE: 0.119021937251091
# Early stopping at epoch 71
# RMSE: 0.11490340530872345
# Early stopping at epoch 73
# RMSE: 0.12782874703407288
# Early stopping at epoch 52
# RMSE: 0.12439553439617157
# Starting acquisition iteration 30
# Early stopping at epoch 65
# RMSE: 0.12572436034679413
# Early stopping at epoch 70
# RMSE: 0.11636461317539215
# Early stopping at epoch 67
# RMSE: 0.11222555488348007
# Early stopping at epoch 56
# RMSE: 0.10508181154727936
# Early stopping at epoch 52
# RMSE: 0.1213187426328659
# Early stopping at epoch 79
# RMSE: 0.11728262901306152
# Early stopping at epoch 67
# RMSE: 0.10703648626804352
# Early stopping at epoch 67
# RMSE: 0.11973278224468231
# Early stopping at epoch 57
# RMSE: 0.11234769225120544
# Early stopping at epoch 68
# RMSE: 0.11257071048021317
# Starting acquisition iteration 40
# Early stopping at epoch 78
# RMSE: 0.11551359295845032
# Early stopping at epoch 57
# RMSE: 0.10574346780776978
# Early stopping at epoch 67
# RMSE: 0.1129986122250557
# Early stopping at epoch 55
# RMSE: 0.10050076246261597
# Early stopping at epoch 56
# RMSE: 0.10879134386777878
# Early stopping at epoch 53
# RMSE: 0.09780170023441315
# Early stopping at epoch 59
# RMSE: 0.10115647315979004
# Early stopping at epoch 47
# RMSE: 0.1011052280664444
# Early stopping at epoch 49
# RMSE: 0.10224296152591705
# Early stopping at epoch 55
# RMSE: 0.09848073869943619
# Starting acquisition iteration 50
# Early stopping at epoch 60
# RMSE: 0.0993085727095604
# Early stopping at epoch 46
# RMSE: 0.10430856049060822
# Early stopping at epoch 55
# RMSE: 0.09946724027395248
# Early stopping at epoch 52
# RMSE: 0.1098981574177742
# Early stopping at epoch 46
# RMSE: 0.10783660411834717
# Early stopping at epoch 46
# RMSE: 0.089354008436203
# Early stopping at epoch 58
# RMSE: 0.10072259604930878
# Early stopping at epoch 47
# RMSE: 0.11452597379684448
# Early stopping at epoch 51
# RMSE: 0.09261617064476013
# Early stopping at epoch 49
# RMSE: 0.10426671802997589
# Starting acquisition iteration 60
# Early stopping at epoch 50
# RMSE: 0.10066084563732147
# Early stopping at epoch 41
# RMSE: 0.0970846489071846
# Early stopping at epoch 49
# RMSE: 0.09833463281393051
# Early stopping at epoch 38
# RMSE: 0.10039196163415909
# Early stopping at epoch 59
# RMSE: 0.08963260799646378
# Early stopping at epoch 47
# RMSE: 0.09702835232019424
# Early stopping at epoch 55
# RMSE: 0.09132970124483109
# Early stopping at epoch 61
# RMSE: 0.12520354986190796
# Early stopping at epoch 34
# RMSE: 0.09059211611747742
# Early stopping at epoch 39
# RMSE: 0.0852932259440422
# Starting acquisition iteration 70
# Early stopping at epoch 36
# RMSE: 0.0877205953001976
# Early stopping at epoch 51
# RMSE: 0.10111326724290848
# Early stopping at epoch 32
# RMSE: 0.11750379949808121
# Early stopping at epoch 40
# RMSE: 0.09948433190584183
# Early stopping at epoch 49
# RMSE: 0.09009535610675812
# Early stopping at epoch 47
# RMSE: 0.10064031183719635
# Early stopping at epoch 36
# RMSE: 0.09484028816223145
# Early stopping at epoch 45
# RMSE: 0.08670905232429504
# Early stopping at epoch 39
# RMSE: 0.09559178352355957
# Early stopping at epoch 36
# RMSE: 0.0843612402677536
# Starting acquisition iteration 80
# Early stopping at epoch 42
# RMSE: 0.09754513949155807
# Early stopping at epoch 37
# RMSE: 0.09126336872577667
# Early stopping at epoch 45
# RMSE: 0.10186318308115005
# Early stopping at epoch 40
# RMSE: 0.10010866075754166
# Early stopping at epoch 39
# RMSE: 0.09352333843708038
# Early stopping at epoch 40
# RMSE: 0.08141785860061646
# Early stopping at epoch 34
# RMSE: 0.08275734633207321
# Early stopping at epoch 56
# RMSE: 0.09966996312141418
# Early stopping at epoch 52
# RMSE: 0.09225299209356308
# Early stopping at epoch 35
# RMSE: 0.09434709697961807
# Starting acquisition iteration 90
# Early stopping at epoch 42
# RMSE: 0.0909491628408432
# Early stopping at epoch 44
# RMSE: 0.08798098564147949
# Early stopping at epoch 40
# RMSE: 0.07947850972414017
# Early stopping at epoch 44
# RMSE: 0.0905500277876854
# Early stopping at epoch 40
# RMSE: 0.08855128288269043
# Early stopping at epoch 40
# RMSE: 0.08302348107099533
# Early stopping at epoch 40
# RMSE: 0.08558245003223419
# Early stopping at epoch 34
# RMSE: 0.08417578786611557
# Early stopping at epoch 36
# RMSE: 0.08604182302951813
# Early stopping at epoch 41
# RMSE: 0.08707679063081741
# Creating training dataset
# Active learning: running for random
# Starting acquisition iteration 0
# Early stopping at epoch 18
# RMSE: 0.2734760642051697
# Early stopping at epoch 70
# RMSE: 0.24334412813186646
# Early stopping at epoch 92
# RMSE: 0.22666974365711212
# Early stopping at epoch 21
# RMSE: 0.24239616096019745
# Early stopping at epoch 83
# RMSE: 0.2300504744052887
# Early stopping at epoch 90
# RMSE: 0.2172728031873703
# RMSE: 0.20138594508171082
# RMSE: 0.19231368601322174
# Early stopping at epoch 98
# RMSE: 0.16225488483905792
# Early stopping at epoch 85
# RMSE: 0.16809090971946716
# Starting acquisition iteration 10
# RMSE: 0.1819721758365631
# Early stopping at epoch 71
# RMSE: 0.160873681306839
# Early stopping at epoch 71
# RMSE: 0.17030583322048187
# Early stopping at epoch 77
# RMSE: 0.15624383091926575
# Early stopping at epoch 78
# RMSE: 0.14953801035881042
# Early stopping at epoch 68
# RMSE: 0.14957432448863983
# Early stopping at epoch 61
# RMSE: 0.15120241045951843
# Early stopping at epoch 63
# RMSE: 0.14829297363758087
# Early stopping at epoch 68
# RMSE: 0.13816256821155548
# Early stopping at epoch 83
# RMSE: 0.1368016004562378
# Starting acquisition iteration 20
# Early stopping at epoch 67
# RMSE: 0.1341872364282608
# Early stopping at epoch 66
# RMSE: 0.13805852830410004
# Early stopping at epoch 45
# RMSE: 0.14208324253559113
# Early stopping at epoch 53
# RMSE: 0.14562316238880157
# Early stopping at epoch 53
# RMSE: 0.13636700809001923
# Early stopping at epoch 48
# RMSE: 0.13598868250846863
# Early stopping at epoch 61
# RMSE: 0.129530668258667
# Early stopping at epoch 59
# RMSE: 0.12731802463531494
# Early stopping at epoch 47
# RMSE: 0.1324891895055771
# Early stopping at epoch 47
# RMSE: 0.12493777275085449
# Starting acquisition iteration 30
# Early stopping at epoch 79
# RMSE: 0.11304052919149399
# Early stopping at epoch 59
# RMSE: 0.12594451010227203
# Early stopping at epoch 32
# RMSE: 0.13336412608623505
# Early stopping at epoch 62
# RMSE: 0.13183578848838806
# Early stopping at epoch 41
# RMSE: 0.12637701630592346
# Early stopping at epoch 61
# RMSE: 0.11098645627498627
# Early stopping at epoch 50
# RMSE: 0.11341503262519836
# Early stopping at epoch 47
# RMSE: 0.11687638610601425
# Early stopping at epoch 65
# RMSE: 0.11163841187953949
# Early stopping at epoch 45
# RMSE: 0.10135754197835922
# Starting acquisition iteration 40
# Early stopping at epoch 51
# RMSE: 0.10470262169837952
# Early stopping at epoch 38
# RMSE: 0.11184429377317429
# Early stopping at epoch 68
# RMSE: 0.1076323464512825
# Early stopping at epoch 55
# RMSE: 0.11300443112850189
# Early stopping at epoch 36
# RMSE: 0.11443815380334854
# Early stopping at epoch 30
# RMSE: 0.12655168771743774
# Early stopping at epoch 40
# RMSE: 0.11047930270433426
# Early stopping at epoch 28
# RMSE: 0.11940643936395645
# Early stopping at epoch 51
# RMSE: 0.10292662680149078
# Early stopping at epoch 31
# RMSE: 0.11218364536762238
# Starting acquisition iteration 50
# Early stopping at epoch 51
# RMSE: 0.10623442381620407
# Early stopping at epoch 61
# RMSE: 0.09615989774465561
# Early stopping at epoch 28
# RMSE: 0.1274302899837494
# Early stopping at epoch 43
# RMSE: 0.10785617679357529
# Early stopping at epoch 39
# RMSE: 0.11203498393297195
# Early stopping at epoch 36
# RMSE: 0.11001525074243546
# Early stopping at epoch 35
# RMSE: 0.10340338945388794
# Early stopping at epoch 39
# RMSE: 0.10390517115592957
# Early stopping at epoch 32
# RMSE: 0.10394490510225296
# Early stopping at epoch 40
# RMSE: 0.11162055283784866
# Starting acquisition iteration 60
# Early stopping at epoch 38
# RMSE: 0.10920485109090805
# Early stopping at epoch 27
# RMSE: 0.11810855567455292
# Early stopping at epoch 41
# RMSE: 0.10328712314367294
# Early stopping at epoch 39
# RMSE: 0.10509641468524933
# Early stopping at epoch 39
# RMSE: 0.10542378574609756
# Early stopping at epoch 26
# RMSE: 0.11275514960289001
# Early stopping at epoch 33
# RMSE: 0.09866385906934738
# Early stopping at epoch 35
# RMSE: 0.09839510917663574
# Early stopping at epoch 32
# RMSE: 0.10173171758651733
# Early stopping at epoch 55
# RMSE: 0.10281236469745636
# Starting acquisition iteration 70
# Early stopping at epoch 40
# RMSE: 0.10374271124601364
# Early stopping at epoch 31
# RMSE: 0.10824413597583771
# Early stopping at epoch 34
# RMSE: 0.1062820553779602
# Early stopping at epoch 27
# RMSE: 0.10963597893714905
# Early stopping at epoch 33
# RMSE: 0.10319152474403381
# Early stopping at epoch 22
# RMSE: 0.11526720970869064
# Early stopping at epoch 29
# RMSE: 0.10745308548212051
# Early stopping at epoch 25
# RMSE: 0.11097096651792526
# Early stopping at epoch 32
# RMSE: 0.09886883199214935
# Early stopping at epoch 30
# RMSE: 0.11211422085762024
# Starting acquisition iteration 80
# Early stopping at epoch 32
# RMSE: 0.10355429351329803
# Early stopping at epoch 24
# RMSE: 0.11128129810094833
# Early stopping at epoch 24
# RMSE: 0.10485362261533737
# Early stopping at epoch 22
# RMSE: 0.11090531200170517
# Early stopping at epoch 32
# RMSE: 0.10229238867759705
# Early stopping at epoch 27
# RMSE: 0.09842974692583084
# Early stopping at epoch 29
# RMSE: 0.09653238952159882
# Early stopping at epoch 34
# RMSE: 0.116573266685009
# Early stopping at epoch 38
# RMSE: 0.09050881117582321
# Early stopping at epoch 30
# RMSE: 0.10826348513364792
# Starting acquisition iteration 90
# Early stopping at epoch 22
# RMSE: 0.1141502857208252
# Early stopping at epoch 29
# RMSE: 0.09479817003011703
# Early stopping at epoch 36
# RMSE: 0.0901382640004158
# Early stopping at epoch 41
# RMSE: 0.09545712172985077
# Early stopping at epoch 28
# RMSE: 0.09483716636896133
# Early stopping at epoch 23
# RMSE: 0.10649116337299347
# Early stopping at epoch 32
# RMSE: 0.1005897969007492
# Early stopping at epoch 27
# RMSE: 0.09549684077501297
# Early stopping at epoch 31
# RMSE: 0.09197454899549484
# Early stopping at epoch 22
# RMSE: 0.10664001852273941
# Creating training dataset
# Active learning: running for pred_variance_naive
# Starting acquisition iteration 0
# Early stopping at epoch 15
# RMSE: 0.297363817691803
# Early stopping at epoch 26
# RMSE: 0.27679580450057983
# Early stopping at epoch 15
# RMSE: 0.28057360649108887
# Early stopping at epoch 84
# RMSE: 0.28341418504714966
# Early stopping at epoch 27
# RMSE: 0.25312304496765137
# Early stopping at epoch 89
# RMSE: 0.21878457069396973
# Early stopping at epoch 84
# RMSE: 0.21544219553470612
# RMSE: 0.19560229778289795
# RMSE: 0.1700364351272583
# Early stopping at epoch 87
# RMSE: 0.17158059775829315
# Starting acquisition iteration 10
# Early stopping at epoch 90
# RMSE: 0.16818629205226898
# Early stopping at epoch 70
# RMSE: 0.17640343308448792
# Early stopping at epoch 74
# RMSE: 0.16220983862876892
# Early stopping at epoch 68
# RMSE: 0.1453414410352707
# Early stopping at epoch 96
# RMSE: 0.14415216445922852
# Early stopping at epoch 70
# RMSE: 0.14279866218566895
# Early stopping at epoch 59
# RMSE: 0.135051429271698
# Early stopping at epoch 69
# RMSE: 0.13025957345962524
# Early stopping at epoch 65
# RMSE: 0.13315382599830627
# Early stopping at epoch 61
# RMSE: 0.1314556896686554
# Starting acquisition iteration 20
# Early stopping at epoch 75
# RMSE: 0.11629705876111984
# Early stopping at epoch 59
# RMSE: 0.11570408195257187
# Early stopping at epoch 89
# RMSE: 0.1105116605758667
# Early stopping at epoch 64
# RMSE: 0.12467901408672333
# Early stopping at epoch 17
# RMSE: 0.2369384616613388
# Early stopping at epoch 65
# RMSE: 0.11952842772006989
# Early stopping at epoch 70
# RMSE: 0.11851973086595535
# Early stopping at epoch 64
# RMSE: 0.10592585057020187
# Early stopping at epoch 65
# RMSE: 0.11243745684623718
# Early stopping at epoch 62
# RMSE: 0.10202569514513016
# Starting acquisition iteration 30
# Early stopping at epoch 65
# RMSE: 0.120265893638134
# Early stopping at epoch 58
# RMSE: 0.09463883191347122
# Early stopping at epoch 63
# RMSE: 0.10720322281122208
# Early stopping at epoch 61
# RMSE: 0.10371501743793488
# Early stopping at epoch 66
# RMSE: 0.10344148427248001
# Early stopping at epoch 66
# RMSE: 0.10790236294269562
# Early stopping at epoch 80
# RMSE: 0.10963422060012817
# Early stopping at epoch 53
# RMSE: 0.0983307734131813
# Early stopping at epoch 89
# RMSE: 0.12284553796052933
# Early stopping at epoch 61
# RMSE: 0.11070442944765091
# Starting acquisition iteration 40
# Early stopping at epoch 50
# RMSE: 0.09839923679828644
# Early stopping at epoch 68
# RMSE: 0.09923262149095535
# Early stopping at epoch 60
# RMSE: 0.10818425565958023
# Early stopping at epoch 60
# RMSE: 0.09525100141763687
# Early stopping at epoch 65
# RMSE: 0.10347519814968109
# Early stopping at epoch 39
# RMSE: 0.11271630227565765
# Early stopping at epoch 52
# RMSE: 0.10694360733032227
# Early stopping at epoch 53
# RMSE: 0.09686465561389923
# Early stopping at epoch 55
# RMSE: 0.09739082306623459
# Early stopping at epoch 53
# RMSE: 0.09511580318212509
# Starting acquisition iteration 50
# Early stopping at epoch 56
# RMSE: 0.11664260923862457
# Early stopping at epoch 48
# RMSE: 0.09501971304416656
# Early stopping at epoch 49
# RMSE: 0.09982725977897644
# Early stopping at epoch 48
# RMSE: 0.09794904291629791
# Early stopping at epoch 58
# RMSE: 0.09065002202987671
# Early stopping at epoch 84
# RMSE: 0.10859718918800354
# Early stopping at epoch 47
# RMSE: 0.09242594242095947
# Early stopping at epoch 49
# RMSE: 0.08940784633159637
# Early stopping at epoch 39
# RMSE: 0.10167411714792252
# Early stopping at epoch 30
# RMSE: 0.11109121143817902
# Starting acquisition iteration 60
# Early stopping at epoch 43
# RMSE: 0.08844500035047531
# Early stopping at epoch 53
# RMSE: 0.08888304978609085
# Early stopping at epoch 46
# RMSE: 0.09039366245269775
# Early stopping at epoch 44
# RMSE: 0.09300895035266876
# Early stopping at epoch 56
# RMSE: 0.08801331371068954
# Early stopping at epoch 40
# RMSE: 0.09367653727531433
# Early stopping at epoch 33
# RMSE: 0.08851749449968338
# Early stopping at epoch 39
# RMSE: 0.08708151429891586
# Early stopping at epoch 52
# RMSE: 0.0859498456120491
# Early stopping at epoch 43
# RMSE: 0.0852031409740448
# Starting acquisition iteration 70
# Early stopping at epoch 38
# RMSE: 0.0850427970290184
# Early stopping at epoch 46
# RMSE: 0.10035980492830276
# Early stopping at epoch 49
# RMSE: 0.10206469148397446
# Early stopping at epoch 56
# RMSE: 0.08436969667673111
# Early stopping at epoch 38
# RMSE: 0.08942648768424988
# Early stopping at epoch 46
# RMSE: 0.08858652412891388
# Early stopping at epoch 36
# RMSE: 0.09330195188522339
# Early stopping at epoch 61
# RMSE: 0.14889581501483917
# Early stopping at epoch 42
# RMSE: 0.08425073325634003
# Early stopping at epoch 35
# RMSE: 0.08864623308181763
# Starting acquisition iteration 80
# Early stopping at epoch 36
# RMSE: 0.08297541737556458
# Early stopping at epoch 39
# RMSE: 0.09161707013845444
# Early stopping at epoch 34
# RMSE: 0.10229793190956116
# Early stopping at epoch 37
# RMSE: 0.09323614090681076
# Early stopping at epoch 33
# RMSE: 0.08735021948814392
# Early stopping at epoch 51
# RMSE: 0.08406797051429749
# Early stopping at epoch 35
# RMSE: 0.09682153165340424
# Early stopping at epoch 41
# RMSE: 0.08471646159887314
# Early stopping at epoch 56
# RMSE: 0.07767214626073837
# Early stopping at epoch 63
# RMSE: 0.0807429775595665
# Starting acquisition iteration 90
# Early stopping at epoch 42
# RMSE: 0.07986024022102356
# Early stopping at epoch 49
# RMSE: 0.08622706681489944
# Early stopping at epoch 46
# RMSE: 0.08374882489442825
# Early stopping at epoch 39
# RMSE: 0.0873241201043129
# Early stopping at epoch 38
# RMSE: 0.09148520976305008
# Early stopping at epoch 42
# RMSE: 0.0823473185300827
# Early stopping at epoch 51
# RMSE: 0.07883764803409576
# Early stopping at epoch 35
# RMSE: 0.08878029137849808
# Early stopping at epoch 41
# RMSE: 0.08073369413614273
# Early stopping at epoch 37
# RMSE: 0.08136708289384842
# Creating training dataset
# Active learning: running for random
# Starting acquisition iteration 0
# Early stopping at epoch 37
# RMSE: 0.26963040232658386
# Early stopping at epoch 16
# RMSE: 0.26686909794807434
# RMSE: 0.23623162508010864
# Early stopping at epoch 68
# RMSE: 0.23490329086780548
# RMSE: 0.2189532220363617
# Early stopping at epoch 90
# RMSE: 0.2119842916727066
# Early stopping at epoch 82
# RMSE: 0.20773018896579742
# Early stopping at epoch 96
# RMSE: 0.16861434280872345
# RMSE: 0.17993606626987457
# Early stopping at epoch 85
# RMSE: 0.17887316644191742
# Starting acquisition iteration 10
# Early stopping at epoch 76
# RMSE: 0.1715405285358429
# Early stopping at epoch 85
# RMSE: 0.15126335620880127
# Early stopping at epoch 69
# RMSE: 0.15779775381088257
# Early stopping at epoch 59
# RMSE: 0.15110406279563904
# Early stopping at epoch 68
# RMSE: 0.15412969887256622
# Early stopping at epoch 90
# RMSE: 0.12913066148757935
# Early stopping at epoch 67
# RMSE: 0.13876430690288544
# Early stopping at epoch 73
# RMSE: 0.13661561906337738
# Early stopping at epoch 58
# RMSE: 0.1425064504146576
# Early stopping at epoch 53
# RMSE: 0.1325916200876236
# Starting acquisition iteration 20
# Early stopping at epoch 63
# RMSE: 0.12242094427347183
# Early stopping at epoch 88
# RMSE: 0.14513914287090302
# Early stopping at epoch 55
# RMSE: 0.12989795207977295
# Early stopping at epoch 48
# RMSE: 0.12672069668769836
# Early stopping at epoch 50
# RMSE: 0.12687277793884277
# Early stopping at epoch 55
# RMSE: 0.12188725173473358
# Early stopping at epoch 56
# RMSE: 0.1119978204369545
# Early stopping at epoch 43
# RMSE: 0.12314396351575851
# Early stopping at epoch 46
# RMSE: 0.11959857493638992
# Early stopping at epoch 45
# RMSE: 0.1285460889339447
# Starting acquisition iteration 30
# Early stopping at epoch 45
# RMSE: 0.11576065421104431
# Early stopping at epoch 49
# RMSE: 0.11866501718759537
# Early stopping at epoch 54
# RMSE: 0.10543588548898697
# Early stopping at epoch 47
# RMSE: 0.10460062325000763
# Early stopping at epoch 54
# RMSE: 0.10450924187898636
# Early stopping at epoch 39
# RMSE: 0.11673816293478012
# Early stopping at epoch 52
# RMSE: 0.11006088554859161
# Early stopping at epoch 55
# RMSE: 0.10985171794891357
# Early stopping at epoch 35
# RMSE: 0.1191951259970665
# Early stopping at epoch 56
# RMSE: 0.10693814605474472
# Starting acquisition iteration 40
# Early stopping at epoch 37
# RMSE: 0.11542303115129471
# Early stopping at epoch 55
# RMSE: 0.10380356758832932
# Early stopping at epoch 37
# RMSE: 0.11159220337867737
# Early stopping at epoch 44
# RMSE: 0.11138400435447693
# Early stopping at epoch 44
# RMSE: 0.09397022426128387
# Early stopping at epoch 37
# RMSE: 0.10700791329145432
# Early stopping at epoch 48
# RMSE: 0.1086391732096672
# Early stopping at epoch 41
# RMSE: 0.10645405203104019
# Early stopping at epoch 51
# RMSE: 0.11530272662639618
# Early stopping at epoch 38
# RMSE: 0.10122355073690414
# Starting acquisition iteration 50
# Early stopping at epoch 30
# RMSE: 0.11175204068422318
# Early stopping at epoch 41
# RMSE: 0.0977422446012497
# Early stopping at epoch 33
# RMSE: 0.11298980563879013
# Early stopping at epoch 34
# RMSE: 0.10017009824514389
# Early stopping at epoch 46
# RMSE: 0.10268276929855347
# Early stopping at epoch 41
# RMSE: 0.10400081425905228
# Early stopping at epoch 27
# RMSE: 0.111723393201828
# Early stopping at epoch 35
# RMSE: 0.10464151948690414
# Early stopping at epoch 28
# RMSE: 0.10825879126787186
# Early stopping at epoch 48
# RMSE: 0.1040637418627739
# Starting acquisition iteration 60
# Early stopping at epoch 45
# RMSE: 0.09573838859796524
# Early stopping at epoch 26
# RMSE: 0.11921712756156921
# Early stopping at epoch 34
# RMSE: 0.10168911516666412
# Early stopping at epoch 40
# RMSE: 0.09042888134717941
# Early stopping at epoch 55
# RMSE: 0.0978415310382843
# Early stopping at epoch 57
# RMSE: 0.10583948343992233
# Early stopping at epoch 33
# RMSE: 0.10169705003499985
# Early stopping at epoch 49
# RMSE: 0.09789285808801651
# Early stopping at epoch 37
# RMSE: 0.0986703410744667
# Early stopping at epoch 35
# RMSE: 0.10060196369886398
# Starting acquisition iteration 70
# Early stopping at epoch 24
# RMSE: 0.11294476687908173
# Early stopping at epoch 27
# RMSE: 0.10448650270700455
# Early stopping at epoch 42
# RMSE: 0.09546473622322083
# Early stopping at epoch 34
# RMSE: 0.09483090043067932
# Early stopping at epoch 43
# RMSE: 0.0868905633687973
# Early stopping at epoch 28
# RMSE: 0.0965445339679718
# Early stopping at epoch 48
# RMSE: 0.10054051876068115
# Early stopping at epoch 31
# RMSE: 0.09804811328649521
# Early stopping at epoch 28
# RMSE: 0.09614034742116928
# Early stopping at epoch 35
# RMSE: 0.09810464084148407
# Starting acquisition iteration 80
# Early stopping at epoch 38
# RMSE: 0.09406552463769913
# Early stopping at epoch 32
# RMSE: 0.09691248089075089
# Early stopping at epoch 31
# RMSE: 0.09140978753566742
# Early stopping at epoch 35
# RMSE: 0.09839781373739243
# Early stopping at epoch 32
# RMSE: 0.09220635145902634
# Early stopping at epoch 32
# RMSE: 0.09509870409965515
# Early stopping at epoch 57
# RMSE: 0.09500518441200256
# Early stopping at epoch 29
# RMSE: 0.093509741127491
# Early stopping at epoch 21
# RMSE: 0.10746392607688904
# Early stopping at epoch 45
# RMSE: 0.09797222167253494
# Starting acquisition iteration 90
# Early stopping at epoch 29
# RMSE: 0.09864158183336258
# Early stopping at epoch 22
# RMSE: 0.10652971267700195
# Early stopping at epoch 47
# RMSE: 0.09536221623420715
# Early stopping at epoch 33
# RMSE: 0.09403753280639648
# Early stopping at epoch 36
# RMSE: 0.09467171132564545
# Early stopping at epoch 25
# RMSE: 0.0951608419418335
# Early stopping at epoch 34
# RMSE: 0.09266849607229233
# Early stopping at epoch 34
# RMSE: 0.0909847766160965
# Early stopping at epoch 25
# RMSE: 0.09567379206418991
# Early stopping at epoch 32
# RMSE: 0.089579738676548
# Creating training dataset
# Active learning: running for pred_variance_naive
# Starting acquisition iteration 0
# Early stopping at epoch 61
# RMSE: 0.2639597952365875
# Early stopping at epoch 76
# RMSE: 0.2967942953109741
# Early stopping at epoch 97
# RMSE: 0.21833789348602295
# Early stopping at epoch 22
# RMSE: 0.2549235224723816
# Early stopping at epoch 88
# RMSE: 0.22597289085388184
# Early stopping at epoch 90
# RMSE: 0.20252662897109985
# RMSE: 0.2138570100069046
# Early stopping at epoch 73
# RMSE: 0.19963575899600983
# RMSE: 0.18097959458827972
# Early stopping at epoch 72
# RMSE: 0.17649056017398834
# Starting acquisition iteration 10
# Early stopping at epoch 68
# RMSE: 0.1757981926202774
# Early stopping at epoch 73
# RMSE: 0.17308276891708374
# Early stopping at epoch 65
# RMSE: 0.17044752836227417
# Early stopping at epoch 72
# RMSE: 0.16571561992168427
# Early stopping at epoch 73
# RMSE: 0.15213169157505035
# Early stopping at epoch 75
# RMSE: 0.14545738697052002
# Early stopping at epoch 82
# RMSE: 0.1340145319700241
# Early stopping at epoch 65
# RMSE: 0.14299464225769043
# Early stopping at epoch 79
# RMSE: 0.126931831240654
# Early stopping at epoch 74
# RMSE: 0.13082844018936157
# Starting acquisition iteration 20
# Early stopping at epoch 83
# RMSE: 0.11692093312740326
# Early stopping at epoch 94
# RMSE: 0.1184600293636322
# Early stopping at epoch 72
# RMSE: 0.12226379662752151
# Early stopping at epoch 70
# RMSE: 0.1190723329782486
# Early stopping at epoch 77
# RMSE: 0.12192694842815399
# Early stopping at epoch 63
# RMSE: 0.11489841341972351
# Early stopping at epoch 16
# RMSE: 0.26085951924324036
# Early stopping at epoch 51
# RMSE: 0.12322727590799332
# Early stopping at epoch 62
# RMSE: 0.11108355969190598
# Early stopping at epoch 64
# RMSE: 0.11440172046422958
# Starting acquisition iteration 30
# Early stopping at epoch 56
# RMSE: 0.23268620669841766
# Early stopping at epoch 83
# RMSE: 0.11175734549760818
# Early stopping at epoch 87
# RMSE: 0.11277054250240326
# Early stopping at epoch 57
# RMSE: 0.11258800327777863
# Early stopping at epoch 69
# RMSE: 0.1213725283741951
# Early stopping at epoch 76
# RMSE: 0.10430625826120377
# Early stopping at epoch 48
# RMSE: 0.09922042489051819
# Early stopping at epoch 65
# RMSE: 0.1025531142950058
# Early stopping at epoch 65
# RMSE: 0.09333985298871994
# Early stopping at epoch 56
# RMSE: 0.0998033955693245
# Starting acquisition iteration 40
# Early stopping at epoch 58
# RMSE: 0.12396212667226791
# Early stopping at epoch 60
# RMSE: 0.09051336348056793
# Early stopping at epoch 62
# RMSE: 0.09918472915887833
# Early stopping at epoch 48
# RMSE: 0.09464108943939209
# Early stopping at epoch 35
# RMSE: 0.11057550460100174
# Early stopping at epoch 42
# RMSE: 0.09901069104671478
# Early stopping at epoch 64
# RMSE: 0.08704634010791779
# Early stopping at epoch 46
# RMSE: 0.09816232323646545
# Early stopping at epoch 52
# RMSE: 0.08988196402788162
# Early stopping at epoch 36
# RMSE: 0.11043862253427505
# Starting acquisition iteration 50
# Early stopping at epoch 65
# RMSE: 0.10197930037975311
# Early stopping at epoch 44
# RMSE: 0.09138869494199753
# Early stopping at epoch 54
# RMSE: 0.09809188544750214
# Early stopping at epoch 44
# RMSE: 0.09081201255321503
# Early stopping at epoch 48
# RMSE: 0.09128354489803314
# Early stopping at epoch 69
# RMSE: 0.10346066206693649
# Early stopping at epoch 48
# RMSE: 0.09115105867385864
# Early stopping at epoch 50
# RMSE: 0.0938459113240242
# Early stopping at epoch 42
# RMSE: 0.09906000643968582
# Early stopping at epoch 44
# RMSE: 0.08913403749465942
# Starting acquisition iteration 60
# Early stopping at epoch 73
# RMSE: 0.09689626842737198
# Early stopping at epoch 45
# RMSE: 0.09577532112598419
# Early stopping at epoch 56
# RMSE: 0.09622398763895035
# Early stopping at epoch 40
# RMSE: 0.09294845908880234
# Early stopping at epoch 62
# RMSE: 0.10352829098701477
# Early stopping at epoch 51
# RMSE: 0.09816648066043854
# Early stopping at epoch 46
# RMSE: 0.08969360589981079
# Early stopping at epoch 41
# RMSE: 0.08077257871627808
# Early stopping at epoch 53
# RMSE: 0.08304839581251144
# Early stopping at epoch 38
# RMSE: 0.08062073588371277
# Starting acquisition iteration 70
# Early stopping at epoch 68
# RMSE: 0.08829447627067566
# Early stopping at epoch 62
# RMSE: 0.12882818281650543
# Early stopping at epoch 44
# RMSE: 0.08604107052087784
# Early stopping at epoch 48
# RMSE: 0.08795913308858871
# Early stopping at epoch 41
# RMSE: 0.08321633189916611
# Early stopping at epoch 44
# RMSE: 0.08666258305311203
# Early stopping at epoch 50
# RMSE: 0.08574271202087402
# Early stopping at epoch 39
# RMSE: 0.08781685680150986
# Early stopping at epoch 43
# RMSE: 0.08276063203811646
# Early stopping at epoch 100
# RMSE: 0.10194622725248337
# Starting acquisition iteration 80
# Early stopping at epoch 38
# RMSE: 0.08093354105949402
# Early stopping at epoch 30
# RMSE: 0.08979526907205582
# Early stopping at epoch 46
# RMSE: 0.09162064641714096
# Early stopping at epoch 38
# RMSE: 0.08978303521871567
# Early stopping at epoch 28
# RMSE: 0.08979468792676926
# Early stopping at epoch 42
# RMSE: 0.08450227975845337
# Early stopping at epoch 48
# RMSE: 0.0938810408115387
# Early stopping at epoch 59
# RMSE: 0.09071413427591324
# Early stopping at epoch 35
# RMSE: 0.08865310251712799
# Early stopping at epoch 37
# RMSE: 0.08643091470003128
# Starting acquisition iteration 90
# Early stopping at epoch 53
# RMSE: 0.10607972741127014
# Early stopping at epoch 31
# RMSE: 0.08797124773263931
# Early stopping at epoch 32
# RMSE: 0.0821002796292305
# Early stopping at epoch 47
# RMSE: 0.08412788808345795
# Early stopping at epoch 76
# RMSE: 0.09280633181333542
# Early stopping at epoch 38
# RMSE: 0.0864291563630104
# Early stopping at epoch 28
# RMSE: 0.09459793567657471
# Early stopping at epoch 30
# RMSE: 0.09485691040754318
# Early stopping at epoch 52
# RMSE: 0.08177739381790161
# Early stopping at epoch 38
# RMSE: 0.07595513761043549
# Creating training dataset
# Active learning: running for random
# Starting acquisition iteration 0
# Early stopping at epoch 87
# RMSE: 0.2666137218475342
# Early stopping at epoch 92
# RMSE: 0.2584613859653473
# Early stopping at epoch 30
# RMSE: 0.2717685103416443
# Early stopping at epoch 68
# RMSE: 0.25406304001808167
# Early stopping at epoch 64
# RMSE: 0.25008419156074524
# Early stopping at epoch 66
# RMSE: 0.22566159069538116
# Early stopping at epoch 82
# RMSE: 0.21110200881958008
# Early stopping at epoch 57
# RMSE: 0.21650996804237366
# Early stopping at epoch 100
# RMSE: 0.1793077290058136
# Early stopping at epoch 83
# RMSE: 0.19013042747974396
# Starting acquisition iteration 10
# Early stopping at epoch 66
# RMSE: 0.19154073297977448
# Early stopping at epoch 88
# RMSE: 0.16310612857341766
# Early stopping at epoch 86
# RMSE: 0.1620795577764511
# Early stopping at epoch 84
# RMSE: 0.14952035248279572
# Early stopping at epoch 63
# RMSE: 0.1575263887643814
# Early stopping at epoch 75
# RMSE: 0.14587776362895966
# Early stopping at epoch 58
# RMSE: 0.15490761399269104
# Early stopping at epoch 66
# RMSE: 0.15199238061904907
# Early stopping at epoch 63
# RMSE: 0.14672821760177612
# Early stopping at epoch 71
# RMSE: 0.1438894271850586
# Starting acquisition iteration 20
# Early stopping at epoch 82
# RMSE: 0.13221049308776855
# Early stopping at epoch 70
# RMSE: 0.12816907465457916
# Early stopping at epoch 64
# RMSE: 0.12339339405298233
# Early stopping at epoch 67
# RMSE: 0.12678295373916626
# Early stopping at epoch 61
# RMSE: 0.14051832258701324
# Early stopping at epoch 50
# RMSE: 0.13769634068012238
# Early stopping at epoch 49
# RMSE: 0.12735874950885773
# Early stopping at epoch 56
# RMSE: 0.12286679446697235
# Early stopping at epoch 53
# RMSE: 0.11926089227199554
# Early stopping at epoch 56
# RMSE: 0.11744363605976105
# Starting acquisition iteration 30
# Early stopping at epoch 45
# RMSE: 0.12592318654060364
# Early stopping at epoch 59
# RMSE: 0.13042153418064117
# Early stopping at epoch 48
# RMSE: 0.11725340783596039
# Early stopping at epoch 65
# RMSE: 0.1162879541516304
# Early stopping at epoch 56
# RMSE: 0.11475804448127747
# Early stopping at epoch 46
# RMSE: 0.12200968712568283
# Early stopping at epoch 67
# RMSE: 0.11467010527849197
# Early stopping at epoch 42
# RMSE: 0.11716839671134949
# Early stopping at epoch 56
# RMSE: 0.10694961249828339
# Early stopping at epoch 39
# RMSE: 0.11602665483951569
# Starting acquisition iteration 40
# Early stopping at epoch 41
# RMSE: 0.11397892236709595
# Early stopping at epoch 58
# RMSE: 0.10606088489294052
# Early stopping at epoch 44
# RMSE: 0.10973967611789703
# Early stopping at epoch 58
# RMSE: 0.11003828793764114
# Early stopping at epoch 47
# RMSE: 0.1023547500371933
# Early stopping at epoch 48
# RMSE: 0.11221057176589966
# Early stopping at epoch 58
# RMSE: 0.10894376784563065
# Early stopping at epoch 37
# RMSE: 0.10879365354776382
# Early stopping at epoch 39
# RMSE: 0.11401035636663437
# Early stopping at epoch 29
# RMSE: 0.1159253939986229
# Starting acquisition iteration 50
# Early stopping at epoch 43
# RMSE: 0.10124451667070389
# Early stopping at epoch 42
# RMSE: 0.10897461324930191
# Early stopping at epoch 50
# RMSE: 0.10961255431175232
# Early stopping at epoch 36
# RMSE: 0.10391392558813095
# Early stopping at epoch 33
# RMSE: 0.11382625252008438
# Early stopping at epoch 35
# RMSE: 0.10896901786327362
# Early stopping at epoch 37
# RMSE: 0.09782946854829788
# Early stopping at epoch 44
# RMSE: 0.10000354051589966
# Early stopping at epoch 47
# RMSE: 0.09190503507852554
# Early stopping at epoch 29
# RMSE: 0.11377226561307907
# Starting acquisition iteration 60
# Early stopping at epoch 26
# RMSE: 0.11218775808811188
# Early stopping at epoch 35
# RMSE: 0.09923232346773148
# Early stopping at epoch 46
# RMSE: 0.09928485751152039
# Early stopping at epoch 36
# RMSE: 0.10228681564331055
# Early stopping at epoch 31
# RMSE: 0.10739745944738388
# Early stopping at epoch 42
# RMSE: 0.09394372999668121
# Early stopping at epoch 50
# RMSE: 0.11698460578918457
# Early stopping at epoch 40
# RMSE: 0.09039971977472305
# Early stopping at epoch 40
# RMSE: 0.09656836837530136
# Early stopping at epoch 36
# RMSE: 0.09108439087867737
# Starting acquisition iteration 70
# Early stopping at epoch 53
# RMSE: 0.09408494085073471
# Early stopping at epoch 36
# RMSE: 0.09630928188562393
# Early stopping at epoch 38
# RMSE: 0.10206130146980286
# Early stopping at epoch 40
# RMSE: 0.09630812704563141
# Early stopping at epoch 37
# RMSE: 0.09681659936904907
# Early stopping at epoch 39
# RMSE: 0.09827399253845215
# Early stopping at epoch 35
# RMSE: 0.09453415125608444
# Early stopping at epoch 41
# RMSE: 0.09598000347614288
# Early stopping at epoch 50
# RMSE: 0.08808392286300659
# Early stopping at epoch 34
# RMSE: 0.09469879418611526
# Starting acquisition iteration 80
# Early stopping at epoch 42
# RMSE: 0.08876284956932068
# Early stopping at epoch 32
# RMSE: 0.10714560747146606
# Early stopping at epoch 28
# RMSE: 0.08864407986402512
# Early stopping at epoch 36
# RMSE: 0.0840182900428772
# Early stopping at epoch 35
# RMSE: 0.10068237781524658
# Early stopping at epoch 37
# RMSE: 0.09809524565935135
# Early stopping at epoch 27
# RMSE: 0.09493279457092285
# Early stopping at epoch 23
# RMSE: 0.10607756674289703
# Early stopping at epoch 39
# RMSE: 0.09051420539617538
# Early stopping at epoch 45
# RMSE: 0.08612998574972153
# Starting acquisition iteration 90
# Early stopping at epoch 31
# RMSE: 0.09229488670825958
# Early stopping at epoch 35
# RMSE: 0.09652812033891678
# Early stopping at epoch 35
# RMSE: 0.10032720863819122
# Early stopping at epoch 38
# RMSE: 0.08807697892189026
# Early stopping at epoch 21
# RMSE: 0.10439792275428772
# Early stopping at epoch 33
# RMSE: 0.08845771849155426
# Early stopping at epoch 30
# RMSE: 0.09206465631723404
# Early stopping at epoch 45
# RMSE: 0.08463389426469803
# Early stopping at epoch 28
# RMSE: 0.09206321090459824
# Early stopping at epoch 23
# RMSE: 0.0934286043047905

# %%
import json
with open("/content/drive/MyDrive/regression_results_mandatory_analytical1.json", "w") as f:
  json.dump(regression_results_1, f)
with open("/content/drive/MyDrive/regression_results_mandatory_analytical2.json", "w") as f:
  json.dump(regression_results_2, f)
with open("/content/drive/MyDrive/regression_results_mandatory_analytical3.json", "w") as f:
  json.dump(regression_results_3, f)
with open("/content/drive/MyDrive/avg_regression_results_mandatory_analytical.json", "w") as f:
  json.dump(avg_regression_results, f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3145432642.py in <cell line: 0>()
#       1 import json
# ----> 2 with open("/content/drive/MyDrive/regression_results_mandatory_analytical1.json", "w") as f:
#       3   json.dump(regression_results_1, f)
#       4 with open("/content/drive/MyDrive/regression_results_mandatory_analytical2.json", "w") as f:
#       5   json.dump(regression_results_2, f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/regression_results_mandatory_analytical1.json'

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, PercentFormatter
names =  ["pred_variance_analytical", "random"]
for i in range(2):
  accs = avg_regression_results[i]
  plt.plot([acc[1] for acc in accs], [acc[0] for acc in accs], label=names[i])


ax = plt.gca()
ax.set_ylim(0.0, 0.3)

ax.yaxis.set_major_locator(MultipleLocator(0.02))
ax.yaxis.set_minor_locator(MultipleLocator(0.005))

ax.grid(True, which="major")
ax.grid(True, which="minor", alpha=0.3)

plt.title("training set size vs RMSE on various acquisition functions")
plt.xlabel("training set size")
plt.ylabel("RMSE")
plt.legend()
plt.show()
